# %%
#Initialisation 
import pandas as pd
from io import StringIO
from scipy import stats

# %%
# CSV data as a string
csv_data = """
FlightNumber,DepartureDate,DepartureTime,ArrivalDate,ArrivalTime,Airline,DelayMinutes
AA1234,09/01/2023,08:30 AM,09/01/2023,10:45 AM,American Airlines,15
DL5678,09/01/2023,01:15 PM,09/01/2023,03:30 PM,Delta,5
UA9101,09/01/2023,05:00 PM,09/01/2023,07:15 PM,United Airlines,25
AA1234,09/01/2023,08:30 AM,09/01/2023,10:45 PM,American Airlines,30
DL5678,09/02/2023,02:00 PM,09/02/2023,04:10 PM,Delta,NaN
UA9101,09/02/2023,05:00 PM,09/02/2023,07:15 PM,United Airlines,20
AA1234,09/02/2023,08:30 PM,09/03/2023,10:45 AM,American Airlines,60
DL5678,09/03/2023,01:00 PM,09/03/2023,03:30 PM,Delta,10
UA9101,09/03/2023,03:00 PM,09/03/2023,05:20 PM,United Airlines,NaN
AA1234,09/03/2023,08:30 AM,09/03/2023,10:00 AM,American Airlines,15
DL5678,09/04/2023,12:30 PM,09/04/2023,02:40 PM,Delta,25
UA9101,09/04/2023,07:00 PM,09/04/2023,09:15 PM,United Airlines,45
"""

# Use StringIO to read the string as a file
data = pd.read_csv(StringIO(csv_data))
df = data
data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>FlightNumber</th>
#       <th>DepartureDate</th>
#       <th>DepartureTime</th>
#       <th>ArrivalDate</th>
#       <th>ArrivalTime</th>
#       <th>Airline</th>
#       <th>DelayMinutes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>AA1234</td>
#       <td>09/01/2023</td>
#       <td>08:30 AM</td>
#       <td>09/01/2023</td>
#       <td>10:45 AM</td>
#       <td>American Airlines</td>
#       <td>15.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>DL5678</td>
#       <td>09/01/2023</td>
#       <td>01:15 PM</td>
#       <td>09/01/2023</td>
# ...

# %%
import pandas as pd
from io import StringIO

# Your CSV data
csv_data = """
FlightNumber,DepartureDate,DepartureTime,ArrivalDate,ArrivalTime,Airline,DelayMinutes
AA1234,09/01/2023,08:30 AM,09/01/2023,10:45 AM,American Airlines,15
DL5678,09/01/2023,01:15 PM,09/01/2023,03:30 PM,Delta,5
UA9101,09/01/2023,05:00 PM,09/01/2023,07:15 PM,United Airlines,25
AA1234,09/01/2023,08:30 AM,09/01/2023,10:45 PM,American Airlines,30
DL5678,09/02/2023,02:00 PM,09/02/2023,04:10 PM,Delta,NaN
UA9101,09/02/2023,05:00 PM,09/02/2023,07:15 PM,United Airlines,20
AA1234,09/02/2023,08:30 PM,09/03/2023,10:45 AM,American Airlines,60
DL5678,09/03/2023,01:00 PM,09/03/2023,03:30 PM,Delta,10
UA9101,09/03/2023,03:00 PM,09/03/2023,05:20 PM,United Airlines,NaN
AA1234,09/03/2023,08:30 AM,09/03/2023,10:00 AM,American Airlines,15
DL5678,09/04/2023,12:30 PM,09/04/2023,02:40 PM,Delta,25
UA9101,09/04/2023,07:00 PM,09/04/2023,09:15 PM,United Airlines,45
"""

# Load the data into a DataFrame
df = pd.read_csv(StringIO(csv_data))

# Convert the data types in one block
df['DepartureDate'] = pd.to_datetime(df['DepartureDate'])
df['ArrivalDate'] = pd.to_datetime(df['ArrivalDate'])
df['DepartureTime'] = pd.to_datetime(df['DepartureTime']).dt.time
df['ArrivalTime'] = pd.to_datetime(df['ArrivalTime']).dt.time
df['DelayMinutes'] = pd.to_numeric(df['DelayMinutes'], errors='coerce')

# Check the results
print(df.dtypes)
df
# Out:
# FlightNumber             object
# DepartureDate    datetime64[ns]
# DepartureTime            object
# ArrivalDate      datetime64[ns]
# ArrivalTime              object
# Airline                  object
# DelayMinutes            float64
# dtype: object
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>FlightNumber</th>
#       <th>DepartureDate</th>
#       <th>DepartureTime</th>
#       <th>ArrivalDate</th>
#       <th>ArrivalTime</th>
#       <th>Airline</th>
#       <th>DelayMinutes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>AA1234</td>
#       <td>2023-09-01</td>
#       <td>08:30:00</td>
#       <td>2023-09-01</td>
# ...

# %%
#1. DATASET ISSUES AND REQUIREMENTS


#  CSV data
csv_data = """
FlightNumber,DepartureDate,DepartureTime,ArrivalDate,ArrivalTime,Airline,DelayMinutes
AA1234,09/01/2023,08:30 AM,09/01/2023,10:45 AM,American Airlines,15
DL5678,09/01/2023,01:15 PM,09/01/2023,03:30 PM,Delta,5
UA9101,09/01/2023,05:00 PM,09/01/2023,07:15 PM,United Airlines,25
AA1234,09/01/2023,08:30 AM,09/01/2023,10:45 PM,American Airlines,30
DL5678,09/02/2023,02:00 PM,09/02/2023,04:10 PM,Delta,NaN
UA9101,09/02/2023,05:00 PM,09/02/2023,07:15 PM,United Airlines,20
AA1234,09/02/2023,08:30 PM,09/03/2023,10:45 AM,American Airlines,60
DL5678,09/03/2023,01:00 PM,09/03/2023,03:30 PM,Delta,10
UA9101,09/03/2023,03:00 PM,09/03/2023,05:20 PM,United Airlines,NaN
AA1234,09/03/2023,08:30 AM,09/03/2023,10:00 AM,American Airlines,15
DL5678,09/04/2023,12:30 PM,09/04/2023,02:40 PM,Delta,25
UA9101,09/04/2023,07:00 PM,09/04/2023,09:15 PM,United Airlines,45
"""

# Load the data into a DataFrame
df = pd.read_csv(StringIO(csv_data))

# 1. Convert DepartureDate and ArrivalDate to datetime
df['DepartureDate'] = pd.to_datetime(df['DepartureDate'], format='%m/%d/%Y')
df['ArrivalDate'] = pd.to_datetime(df['ArrivalDate'], format='%m/%d/%Y')

# 2. Convert DepartureTime and ArrivalTime to 24-hour time format
df['DepartureTime'] = pd.to_datetime(df['DepartureTime'], format='%I:%M %p').dt.time
df['ArrivalTime'] = pd.to_datetime(df['ArrivalTime'], format='%I:%M %p').dt.time

# 3. Handle missing values in DelayMinutes (replace NaN with 0)
df['DelayMinutes'] = pd.to_numeric(df['DelayMinutes'], errors='coerce').fillna(0)

# 4. Remove duplicate flight entries 
df = df.drop_duplicates(subset=['FlightNumber', 'DepartureDate', 'DepartureTime', 'ArrivalDate', 'ArrivalTime'])

# 5. Correct Inconsistent Time Entries 
def check_time_inconsistency(row):
    dep_datetime = pd.to_datetime(f"{row['DepartureDate']} {row['DepartureTime']}")
    arr_datetime = pd.to_datetime(f"{row['ArrivalDate']} {row['ArrivalTime']}")
    if arr_datetime < dep_datetime:
        # If arrival time is on the same day but before the departure time, we assume arrival is the next day
        arr_datetime += pd.Timedelta(days=1)
    return arr_datetime.time()

df['ArrivalTime'] = df.apply(check_time_inconsistency, axis=1)

# View the cleaned DataFrame
#print(df)
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>FlightNumber</th>
#       <th>DepartureDate</th>
#       <th>DepartureTime</th>
#       <th>ArrivalDate</th>
#       <th>ArrivalTime</th>
#       <th>Airline</th>
#       <th>DelayMinutes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>AA1234</td>
#       <td>2023-09-01</td>
#       <td>08:30:00</td>
#       <td>2023-09-01</td>
#       <td>10:45:00</td>
#       <td>American Airlines</td>
#       <td>15.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>DL5678</td>
#       <td>2023-09-01</td>
#       <td>13:15:00</td>
#       <td>2023-09-01</td>
# ...

# %%
import pandas as pd
from io import StringIO

# Your CSV data
csv_data = """
FlightNumber,DepartureDate,DepartureTime,ArrivalDate,ArrivalTime,Airline,DelayMinutes
AA1234,09/01/2023,08:30 AM,09/01/2023,10:45 AM,American Airlines,15
DL5678,09/01/2023,01:15 PM,09/01/2023,03:30 PM,Delta,5
UA9101,09/01/2023,05:00 PM,09/01/2023,07:15 PM,United Airlines,25
AA1234,09/01/2023,08:30 AM,09/01/2023,10:45 PM,American Airlines,30
DL5678,09/02/2023,02:00 PM,09/02/2023,04:10 PM,Delta,NaN
UA9101,09/02/2023,05:00 PM,09/02/2023,07:15 PM,United Airlines,20
AA1234,09/02/2023,08:30 PM,09/03/2023,10:45 AM,American Airlines,60
DL5678,09/03/2023,01:00 PM,09/03/2023,03:30 PM,Delta,10
UA9101,09/03/2023,03:00 PM,09/03/2023,05:20 PM,United Airlines,NaN
AA1234,09/03/2023,08:30 AM,09/03/2023,10:00 AM,American Airlines,15
DL5678,09/04/2023,12:30 PM,09/04/2023,02:40 PM,Delta,25
UA9101,09/04/2023,07:00 PM,09/04/2023,09:15 PM,United Airlines,45
"""

# Load the data into a DataFrame
df = pd.read_csv(StringIO(csv_data))

# 1. Convert DepartureDate and ArrivalDate to datetime
df['DepartureDate'] = pd.to_datetime(df['DepartureDate'], format='%m/%d/%Y')
df['ArrivalDate'] = pd.to_datetime(df['ArrivalDate'], format='%m/%d/%Y')

# 2. Convert DepartureTime and ArrivalTime to 24-hour time format
df['DepartureTime'] = pd.to_datetime(df['DepartureTime'], format='%I:%M %p').dt.time
df['ArrivalTime'] = pd.to_datetime(df['ArrivalTime'], format='%I:%M %p').dt.time

# 3. Handle missing values in DelayMinutes (replace NaN with 0)
df['DelayMinutes'] = pd.to_numeric(df['DelayMinutes'], errors='coerce').fillna(0)

# 4. Swap DepartureTime and ArrivalTime if ArrivalTime is earlier on the same day
def swap_time_if_needed(row):
    dep_datetime = pd.to_datetime(f"{row['DepartureDate']} {row['DepartureTime']}")
    arr_datetime = pd.to_datetime(f"{row['ArrivalDate']} {row['ArrivalTime']}")
    
    # Check if dates are the same and arrival is before departure
    if row['DepartureDate'] == row['ArrivalDate'] and arr_datetime < dep_datetime:
        # Swap the times
        row['DepartureTime'], row['ArrivalTime'] = row['ArrivalTime'], row['DepartureTime']
    return row

# Apply the swapping function to each row
df = df.apply(swap_time_if_needed, axis=1)

# View the updated DataFrame
#print(df)
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>FlightNumber</th>
#       <th>DepartureDate</th>
#       <th>DepartureTime</th>
#       <th>ArrivalDate</th>
#       <th>ArrivalTime</th>
#       <th>Airline</th>
#       <th>DelayMinutes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>AA1234</td>
#       <td>2023-09-01</td>
#       <td>08:30:00</td>
#       <td>2023-09-01</td>
#       <td>10:45:00</td>
#       <td>American Airlines</td>
#       <td>15.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>DL5678</td>
#       <td>2023-09-01</td>
#       <td>13:15:00</td>
#       <td>2023-09-01</td>
# ...

# %% [markdown]
# #Actual Start do check it form here
# ## put initialisation cell below and do check

# %%
#  CSV data
csv_data = """
FlightNumber,DepartureDate,DepartureTime,ArrivalDate,ArrivalTime,Airline,DelayMinutes
AA1234,09/01/2023,08:30 AM,09/01/2023,10:45 AM,American Airlines,15
DL5678,09/01/2023,01:15 PM,09/01/2023,03:30 PM,Delta,5
UA9101,09/01/2023,05:00 PM,09/01/2023,07:15 PM,United Airlines,25
AA1234,09/01/2023,08:30 AM,09/01/2023,10:45 PM,American Airlines,30
DL5678,09/02/2023,02:00 PM,09/02/2023,04:10 PM,Delta,NaN
UA9101,09/02/2023,05:00 PM,09/02/2023,07:15 PM,United Airlines,20
AA1234,09/02/2023,08:30 PM,09/03/2023,10:45 AM,American Airlines,60
DL5678,09/03/2023,01:00 PM,09/03/2023,03:30 PM,Delta,10
UA9101,09/03/2023,03:00 PM,09/03/2023,05:20 PM,United Airlines,NaN
AA1234,09/03/2023,08:30 AM,09/03/2023,10:00 AM,American Airlines,15
DL5678,09/04/2023,12:30 PM,09/04/2023,02:40 PM,Delta,25
UA9101,09/04/2023,07:00 PM,09/04/2023,09:15 PM,United Airlines,45
"""

# Load the data into a DataFrame
df = pd.read_csv(StringIO(csv_data))

# 1. Convert DepartureDate and ArrivalDate to datetime
df['DepartureDate'] = pd.to_datetime(df['DepartureDate'], format='%m/%d/%Y')
df['ArrivalDate'] = pd.to_datetime(df['ArrivalDate'], format='%m/%d/%Y')

# 2. Convert DepartureTime and ArrivalTime to 24-hour time format
df['DepartureTime'] = pd.to_datetime(df['DepartureTime'], format='%I:%M %p').dt.time
df['ArrivalTime'] = pd.to_datetime(df['ArrivalTime'], format='%I:%M %p').dt.time

# 3. Handle missing values in DelayMinutes (replace NaN with 0)
df['DelayMinutes'] = pd.to_numeric(df['DelayMinutes'], errors='coerce').fillna(0)

# 4. Swap DepartureTime and ArrivalTime if ArrivalTime is earlier on the same day
def swap_time_if_needed(row):
    dep_datetime = pd.to_datetime(f"{row['DepartureDate']} {row['DepartureTime']}")
    arr_datetime = pd.to_datetime(f"{row['ArrivalDate']} {row['ArrivalTime']}")
    
    # Check if dates are the same and arrival is before departure
    if row['DepartureDate'] == row['ArrivalDate'] and arr_datetime < dep_datetime:
        # Swap the times
        row['DepartureTime'], row['ArrivalTime'] = row['ArrivalTime'], row['DepartureTime']
    return row

# Apply the swapping function to each row
df = df.apply(swap_time_if_needed, axis=1)

# 5. Calculate FlightDuration
df['DepartureDateTime'] = pd.to_datetime(df['DepartureDate'].astype(str) + ' ' + df['DepartureTime'].astype(str))
df['ArrivalDateTime'] = pd.to_datetime(df['ArrivalDate'].astype(str) + ' ' + df['ArrivalTime'].astype(str))

# Calculate the flight duration in minutes
df['FlightDurationMinute'] = (df['ArrivalDateTime'] - df['DepartureDateTime']).dt.total_seconds() / 60

# Drop the 'DepartureDateTime' and 'ArrivalDateTime' columns
df = df.drop(columns=['DepartureDateTime', 'ArrivalDateTime'])

# View the updated DataFrame

df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>FlightNumber</th>
#       <th>DepartureDate</th>
#       <th>DepartureTime</th>
#       <th>ArrivalDate</th>
#       <th>ArrivalTime</th>
#       <th>Airline</th>
#       <th>DelayMinutes</th>
#       <th>FlightDurationMinute</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>AA1234</td>
#       <td>2023-09-01</td>
#       <td>08:30:00</td>
#       <td>2023-09-01</td>
#       <td>10:45:00</td>
#       <td>American Airlines</td>
#       <td>15.0</td>
#       <td>135.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>DL5678</td>
#       <td>2023-09-01</td>
# ...

# %%
#DATA ANALYSIS

# Assuming 'df' is your DataFrame with the 'DelayMinutes' column

# 1. Descriptive Statistics
delay_stats = df['DelayMinutes'].describe()
print(delay_stats)

# 2. Histogram of Delays
plt.figure(figsize=(10, 5))
sns.histplot(df['DelayMinutes'], bins=20, kde=True)
plt.title('Distribution of Flight Delays')
plt.xlabel('Delay Minutes')
plt.ylabel('Frequency')
plt.axvline(df['DelayMinutes'].mean(), color='red', linestyle='dashed', linewidth=1, label='Mean')
plt.axvline(df['DelayMinutes'].median(), color='yellow', linestyle='dashed', linewidth=1, label='Median')
plt.legend()
plt.show()

# 3. Box Plot of Delays
plt.figure(figsize=(10, 5))
sns.boxplot(x=df['DelayMinutes'])
plt.title('Box Plot of Flight Delays')
plt.xlabel('Delay Minutes')
plt.show()

# 4. Time Series Analysis (if DepartureDate is in the DataFrame)
df['DepartureDate'] = pd.to_datetime(df['DepartureDate'])
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='DepartureDate', y='DelayMinutes', marker='o')
plt.title('Delays Over Time')
plt.xlabel('Departure Date')
plt.ylabel('Delay Minutes')
plt.xticks(rotation=45)
plt.show()
# Out:
# count    12.000000
# mean     20.833333
# std      17.943514
# min       0.000000
# 25%       8.750000
# 50%      17.500000
# 75%      26.250000
# max      60.000000
# Name: DelayMinutes, dtype: float64

# %%
# 1. Calculate Average Delay for Each Airline
average_delay = df.groupby('Airline')['DelayMinutes'].mean().reset_index()
average_delay.columns = ['Airline', 'AverageDelay']
print(average_delay)

# 2. Convert DepartureTime to total minutes since midnight for plotting
# Extract hours and minutes from the existing DepartureTime
df['DepartureTime'] = df['DepartureTime'].apply(lambda x: x.hour * 60 + x.minute)

# Create a scatter plot
plt.figure(figsize=(12, 6))
sns.scatterplot(x=df['DepartureTime'], y=df['DelayMinutes'], hue=df['Airline'])
plt.title('Relationship Between Flight Delays and Departure Times')
plt.xlabel('Departure Time (minutes since midnight)')
plt.ylabel('Delay Minutes')
plt.xticks(rotation=45)
plt.grid()
plt.show()
# Out:
#              Airline  AverageDelay
# 0  American Airlines          30.0
# 1              Delta          10.0
# 2    United Airlines          22.5

# %%
# Step: Perform ANOVA test to check for differences in delays between airlines
airline_groups = [group['DelayMinutes'].values for name, group in data.groupby('Airline')]

# Perform ANOVA
f_stat, p_value = stats.f_oneway(*airline_groups)

# Output results
print(f'F-statistic: {f_stat:.4f}, p-value: {p_value:.4f}')

# Interpret the p-value
alpha = 0.05
if p_value < alpha:
    print("There is a significant difference in delays between airlines.")
else:
    print("There is no significant difference in delays between airlines.")
# Out:
# F-statistic: nan, p-value: nan
# There is no significant difference in delays between airlines.
